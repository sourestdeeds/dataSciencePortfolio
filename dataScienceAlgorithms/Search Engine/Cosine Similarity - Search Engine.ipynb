# %% [markdown]
# # Create A Simple Search Engine Using Python
# ### Information retrieval using cosine similarity and term-document matrix with TF-IDF weighting.
#
# The first thing that we have to do is to retrieve the documents from the Internet. In this case, we can use web scraping to extract documents from a website. I will scrape documents from kompas.com on sport category, especially on the popular articles. Because of the documents are using HTML format, we initialize a BeautifulSoup object to parse the HTML file, so we can extract each element that we want much easier.

# %%
import re
import string
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import TfidfVectorizer

def retrieve_docs_and_clean():
  # Scrape the website
  r = requests.get('https://skyandtelescope.org/astronomy-news/exoplanets/')
  soup = BeautifulSoup(r.content, 'html.parser')

  link = []
  for i in soup.find('div', {'class':'archive'}).find_all('aarchive'):
      i['href'] = i['href'] + '?page=all'
      link.append(i['href'])

  # Retrieve Paragraphs
  documents = []
  for i in link:
      r = requests.get(i)
      soup = BeautifulSoup(r.content, 'html.parser')

      sen = []
      for i in soup.find('div', {'class':'read__content'}).find_all('p'):
          sen.append(i.text)
      documents.append(' '.join(sen))

  # Clean Paragraphs
  documents_clean = []
  for d in documents:
      document_test = re.sub(r'[^\x00-\x7F]+', ' ', d)
      document_test = re.sub(r'@\w+', '', document_test)
      document_test = document_test.lower()
      document_test = re.sub(r'[%s]' % re.escape(string.punctuation), ' ', document_test)
      document_test = re.sub(r'[0-9]', '', document_test)
      document_test = re.sub(r'\s{2,}', ' ', document_test)
      documents_clean.append(document_test)

  return documents_clean

def get_similar_articles(q, df):
    print("Query:", q)
    print('-'*100)

    # Convert the query become a vector
    q = [q]
    q_vec = vectorizer.transform(q).toarray().reshape(df.shape[0],)

    # Calculate the similarity
    sim = {}
    for i in range(10):
        sim[i] = np.dot(df.loc[:, i].values, q_vec) / np.linalg.norm(df.loc[:, i]) * np.linalg.norm(q_vec)
    
    # Sort the values
    sim_sorted = sorted(sim.items(), key=lambda x: x[1], reverse=True)
    
    # Print the articles and similarity values
    for k, v in sim_sorted:
        if v != 0.0:
            print("Highest Cosine Similarity:", v)
            print(docs[k])
            print()

# %% [markdown]
# ## Term-Document Matrix
#
# It consists of rows that represent by each token (term) from all documents, and the columns consist of the identifier of the document. Inside of the cell is the number of frequency of each word that is weighted by some number.

# %%
docs = retrieve_docs_and_clean()

# Create Term-Document Matrix with TF-IDF weighting

# Instantiate a TfidfVectorizer object
vectorizer = TfidfVectorizer()
# Fits the data and transforms it as a vector
X = vectorizer.fit_transform(docs)

# Create a DataFrame and set the vocabulary as the index
df = pd.DataFrame(X.T.toarray(), index=vectorizer.get_feature_names())
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/ph/9w0w89cd5pq1d7z1_kn2mt8m0000gp/T/ipykernel_12854/3864677331.py in <module>
#       6 vectorizer = TfidfVectorizer()
#       7 # Fits the data and transforms it as a vector
# ----> 8 X = vectorizer.fit_transform(docs)
#       9
#      10 # Create a DataFrame and set the vocabulary as the index
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1848         """
#    1849         self._check_params()
# -> 1850         X = super().fit_transform(raw_documents)
#    1851         self._tfidf.fit(X)
#    1852         # X is already a transformed view of raw_documents so
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1201         max_features = self.max_features
#    1202
# -> 1203         vocabulary, X = self._count_vocab(raw_documents,
#    1204                                           self.fixed_vocabulary_)
#    1205
#
# /usr/local/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1132             vocabulary = dict(vocabulary)
#    1133             if not vocabulary:
# -> 1134                 raise ValueError("empty vocabulary; perhaps the documents only"
#    1135                                  " contain stop words")
#    1136
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
q1 = 'barcelona'

get_similar_articles(q1, df)
# Out:
# Query: barcelona
# ----------------------------------------------------------------------------------------------------
# Highest Cosine Similarity: 0.06796391501095142
# kompas com hasil liga champions pada selasa hingga rabu memastikan dua tim melaju ke babak besar kedua tim itu adalah juventus dan bayern muenchen kepastian juventus dan bayern muenchen lolos fase knockout didapat setelah melakoni pertandingan kontra lawan masing masing pada matchday keempat fase grup liga champions musim ini juventus yang menjamu zenit st petersburg di allianz stadium rabu dini hari wib meraih kemenangan bianconeri julukan juventus menang meyakinkan berkat paulo dybala gol federico chiesa dan alvaro morata baca juga hasil juventus vs zenit bianconeri lolos ke besar liga champions sementara itu gol gol zenit tercipta dari gol bunuh diri leonardo bonucci dan aksi sardar azmoun berkat kemenangan ini juventus makin kokoh di puncak klasemen grup h liga champions dapatkan informasi inspirasi dan insight di email kamu daftarkan email pasukan massimiliano allegri itu mengoleksi poin sempurna hasil dari selalu menang dalam empat pertandingan pertama juventus mengungguli chelsea poin zenit dan malmo yang secara berurutan menempati peringkat dengan hanya ada dua pertandingan tersisa di grup h perolehan poin juventus sudah tidak mungkin disalip oleh tim peringkat ketiga yaitu zenit sementara itu bayern muenchen juga memastikan tempat di besar liga champions seusai menang atas benfica dalam pertandingan yang digelar di allianz arena baca juga hasil bayern vs benfica menang die roten ke besar liga champions robert lewandowski mencetak hattrick atau tiga gol dalam kemenangan bayern sementara itu dua gol lainnya dibukuan serge gnabry dan leroy sane seperti halnya juventus bayern juga kokoh di puncak klasemen dengan koleksi poin hasil dari empat kemenangan pada laga grup e lainnya barcelona meraih kemenangan dynamo kiev berkat gol ansu fati pada menit ke hasil tersebut membuat barcelona menggeser benfica dan kini menempati posisi kedua klasemen dengan raihan poin kemenangan dengan skor serupa juga diraih chelsea yang menyambangi markas malmo chelsea menang berkat gol hakim ziyech baca juga jadwal liga champions tim berpeluang lolos ke besar pekan ini sementara itu man united berhasil selamat dari kekalahan saat bertanding di markas atalanta stadion atleti azzurri d italia setelah menyamakan kedudukan menjelang babak pertama berakhir man united kembali tertinggal pada pertengahan babak kedua setelah kebobolan gol duvan zapata skor tersebut bertahan hingga injury time babak kedua sebelum cristiano ronaldo mencetak gol dan menyamakan skor aksi ronaldo tersebut menjadi gol terakhir dalam pertandingan atalanta vs man united dan laga tuntas dengan skor imbang
#
# Highest Cosine Similarity: 0.03389584945651111
# kompas com klasemen liga champions tak mengalami banyak perubahan setelah rangkaian pertandingan hari pertama matchday keempat selesai manchester united mu masih menempati puncak klasemen grup h setan merah mengoleksi tujuh poin dari empat pertandingan poin terbaru man united dapatkan dari hasil imbang melawan atalanta di stadion gewiss rabu dini hari wib pada laga tersebut man united dua kali tertinggal dari atalanta sebelum bisa mengamankan skor sama kuat gawang man united jebol pada menit ke akibat gol josip ilicic tetapi bisa segera dibalas via cristiano ronaldo baca juga hasil liga champions ronaldo jadi pahlawan atalanta vs man united imbang atalanta kembali megoyak jala man united pada menit ke lewat duvan zapata namun gol ronaldo pada masa injury time menyelamatkan mu dari kekalahan dapatkan informasi inspirasi dan insight di email kamu daftarkan email meski saat ini berada di puncak klasemen grup h posisi manchester united belum aman dan rawan lengser pasalnya jarak poin man united dengan tiga tim di bawahnya tak berbeda jauh bahkan ada yang menyamai secara berurutan tim tim yang mengekor the red devils adalah villarreal poin atalanta dan young boys masih ada dua pertandingan ke depan urutan peringkat di klasemen grup h bisa berubah baca juga hasil juventus vs zenit bianconeri lolos ke besar liga champions beralih ke grup lain di grup e bayern muenchen makin kokoh di puncak klasemen dengan koleksi poin dari empat laga die roten baru saja menambah pundi pundi poin mereka usai menang besar atas benfica di stadion allianz arena dini hari tadi lima gol bayern dicetak oleh robert lewandowski serge gnabry dan leroy sane sementara dua gol balasan dari tim tamu benfica tercatat atas nama morato dan darwin nunez berkat kemenangan tersebut bayern muenchen juga dipastikan lolos ke babak besar liga champions baca juga hasil dynamo kiev vs barcelona gol ansu fati menangkan blaugrana langkah bayern juga diikuti oleh klub penghuni grup h liga champions juventus juventus menyegel tiket fase gugur liga champions selepas menang atas zenit st petersburg di allianz stadium paulo dybala menjadi bintang kemenangan juventus dengan torehan dua golnya pada menit ke dan penalti dua gol si nyonya tua lainnya dibukukan oleh federico chiesa dan alvaro morata adapun gol gol balasan zenit tercipta dari bunuh diri leonardo bonucci dan sumbangsih sardar azmoun dengan kemenangan ini juventus mantap di puncak klasemen grup h dengan poin sempurna dari empat laga rangkaian pertandingan matchday keempat liga champions berlanjut malam ini atau kamis dini hari wib dengan menampilkan delapan partai tersisa keterangan no peringkatd dimainkanm menangs serik kalah selisih golp poin update terakhir rabu pukul wib
#
# Highest Cosine Similarity: 0.022238170442522253
# kompas com manchester united bermain imbang dengan atalanta pada matchday keempat grup f liga champions pertandingan atalanta vs man united yang berlangsung di stadion atleti azzurri d italia rabu dini hari wib berakhir dengan skor sebanyak dua gol atalanta masing masing dicetak oleh josip ilicic dan duvan zapata man united kemudian menghasilkan dua gol balasan yang semuanya dibukukan oleh cristiano ronaldo pada injury time tepatnya menit ke dan baca juga atalanta vs man united solskjaer silahkan terus kritik saya ulasan pertandingan man united langsung berusaha menekan atalanta setelah peluit kickoff dibunyikan wasit slavko vincic dapatkan informasi inspirasi dan insight di email kamu daftarkan email cristiano roanaldo melepaskan tendangan dari luar kotak penalti yang mengarah tepat ke gawang atalanta akan tetapi tembakan ronaldo bisa dibaca kiper juan musso man united nyaris mencetak gol saat pertandingan memasuki menit kelima tendangan scott mctominay mengenai pemain lain sehingga arah bola berubah hal tersebut membuat juan musso mati langkah dan tak mampu menjangkau si kulit bundar namun bola hanya bergulir dan membentur tiang gawang sebelum bisa diamankan pemain atalanta meski tampak mendominasi man united justru kebobolan terlebih dahulu pada menit ke melalui gol josip ilicic yang memanfaatkan umpan silang duvan zapata david de gea sebenarnya bisa melakukan penyelamatan karena bola langsung mengarah ke badannya akan tetapi si kulit bulat justru melewati lengannya dan masuk ke gawang man united man united hampir kebobolan untuk kedua kalinya pada menit ke melalui aksi duvan zapata andai eric bailly gagal melakukan blok setan merah julukan man united berhasil menyamakan kedudukan pada menit ke berkat kerja sama cristiano ronaldo mason greenwood dan bruno fernandes gol berawal dari operan ronaldo ke greenwood yang diteruskan ke fernandes bruno fernandes kemudian mengembalikan bola dengan umpan backheels yang langsung dituntaskan ronaldo menjadi sebuah gol skor pun bertahan hingga babak pertama berakhir baca juga hasil malmo vs chelsea the blues menang ziyech ukir catatan manis bruno fernandes hampir membawa man united berbalik unggul pada menit menit awal babak kedua namun tembakannya bisa diblok pemain atalanta jose luis palomino man united kembali tertinggal pada menit ke akibat gol duvan zapata seusai menerima umpan palomino zapata menggiring bola menuju kotak penalti dan berhadapan dengan de gea maguire mencoba menghentikannya tetapi zapata lebih dulu melepaskan tembakan melewati de gea dan bola bersarang di gawang man united wasit meninjau tayangan ulang var video assistant referee karena ada potensi offside namun var mengonfirmasi bahwa gol tersebut sah skor untuk atalanta pemain pengganti luis muriel memberikan ancaman kepada lini pertahanan man united pada menit ke beruntung bagi man united tendangan lurus muriel masih bisa diamankan de gea david de gea kembali melakukan penyalamatan kiper asal spanyol itu berhasil menepis tendangan keras duvan zapata pada menit ke baca juga hasil dynamo kiev vs barcelona gol ansu fati menangkan blaugrana kemenangan atalanta yang sudah di depan mata buyar setelah cristiano ronaldo kembali mencetak gol pada injury time tepatnya menit ke setelah memanfaatkan assist mason greenwood gol tersebut sekaligus memastikan pertandingan berakhir imbang dengan skor susunan pemain atalanta vs man united atalanta musso gk de roon demiral palomino zappacosta freuler koopmeiners maehle ilicic luis muriel pasalic djimsiti zapata pemain cadangan rossi sportiello miranchuk malinovskyi pezzella piccoli lovato scalvini pelatih gian piero gasperini manchester united de gea gk wan bissaka bailly varane maguire shaw fernandes van de beek mctominay sancho pogba matic rashford cavani ronaldo pemain cadangan juan mata fred lingard martial telles dean henderson diogo dalot pelatih ole gunnar solskjaer keterangan no peringkatd dimainkanm menangs serik kalah selisih golp poin update terakhir rabu pukul wib

# %%
r = requests.get('https://skyandtelescope.org/astronomy-news/exoplanets/')
soup = BeautifulSoup(r.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]><html class="no-js ie ie6 lt-ie9 lt-ie8 lt-ie7" lang="en-US" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:addthis="https://www.addthis.com/help/api-spec" > <![endif]-->
# <!--[if IE 7]><html class="no-js ie ie7 lt-ie9 lt-ie8" lang="en-US" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:addthis="https://www.addthis.com/help/api-spec" > <![endif]-->
# <!--[if IE 8]><html class="no-js ie ie8 lt-ie9" lang="en-US" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:addthis="https://www.addthis.com/help/api-spec" > <![endif]-->
# <!--[if gt IE 8]><!--><html class="no-js" lang="en-US" xmlns:addthis="https://www.addthis.com/help/api-spec" xmlns:fb="https://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <!-- Start after head script -->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NJ7CPQ7');</script>
# <!-- End Google Tag Manager -->
# <!-- End after head script -->
# <meta charset="utf-8"/>
# <title>
#                             Exoplanets News | The Latest on Alien Worlds - Sky &amp; Telescope
#                     </title>
# <meta content="The essential guide to astronomy" name="description"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-8cb8ee238900f71e051",applicationID:"517838593"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n){return function(){return o(t,[u.now()].concat(f(arguments)),e?null:this,n),e?void 0:this}}var o=t("handle"),a=t(8),f=t(9),c=t("ee").get("tracer"),u=t("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var d=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],p="api-",l=p+"ixn-";a(d,function(t,e){s[e]=i(p+e,!0,"api")}),s.addPageAction=i(p+"addPageAction",!0),s.setCurrentRouteName=i(p+"routeName",!0),e.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(t,e){var n={},r=this,i="function"==typeof e;return o(l+"tracer",[u.now(),t,n],r),function(){if(c.emit((i?"":"no-")+"fn-start",[u.now(),r,i],n),i)try{return e.apply(this,arguments)}catch(t){throw c.emit("fn-err",[arguments,this,t],n),t}finally{c.emit("fn-end",[u.now()],n)}}}};a("actionText,setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(t,e){m[e]=i(l+e)}),newrelic.noticeError=function(t,e){"string"==typeof t&&(t=new Error(t)),o("err",[t,u.now(),!1,e])}},{}],2:[function(t,e,n){function r(t){if(NREUM.init){for(var e=NREUM.init,n=t.split("."),r=0;r<n.length-1;r++)if(e=e[n[r]],"object"!=typeof e)return;return e=e[n[n.length-1]]}}e.exports={getConfiguration:r}},{}],3:[function(t,e,n){function r(){return f.exists&&performance.now?Math.round(performance.now()):(o=Math.max((new Date).getTime(),o))-a}function i(){return o}var o=(new Date).getTime(),a=o,f=t(10);e.exports=r,e.exports.offset=a,e.exports.getLastTimestamp=i},{}],4:[function(t,e,n){function r(t){return!(!t||!t.protocol||"file:"===t.protocol)}e.exports=r},{}],5:[function(t,e,n){function r(t,e){var n=t.getEntries();n.forEach(function(t){"first-paint"===t.name?d("timing",["fp",Math.floor(t.startTime)]):"first-contentful-paint"===t.name&&d("timing",["fcp",Math.floor(t.startTime)])})}function i(t,e){var n=t.getEntries();n.length>0&&d("lcp",[n[n.length-1]])}function o(t){t.getEntries().forEach(function(t){t.hadRecentInput||d("cls",[t])})}function a(t){if(t instanceof m&&!g){var e=Math.round(t.timeStamp),n={type:t.type};e<=p.now()?n.fid=p.now()-e:e>p.offset&&e<=Date.now()?(e-=p.offset,n.fid=p.now()-e):e=p.now(),g=!0,d("timing",["fi",e,n])}}function f(t){"hidden"===t&&d("pageHide",[p.now()])}if(!("init"in NREUM&&"page_view_timing"in NREUM.init&&"enabled"in NREUM.init.page_view_timing&&NREUM.init.page_view_timing.enabled===!1)){var c,u,s,d=t("handle"),p=t("loader"),l=t(7),m=NREUM.o.EV;if("PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver){c=new PerformanceObserver(r);try{c.observe({entryTypes:["paint"]})}catch(v){}u=new PerformanceObserver(i);try{u.observe({entryTypes:["largest-contentful-paint"]})}catch(v){}s=new PerformanceObserver(o);try{s.observe({type:"layout-shift",buffered:!0})}catch(v){}}if("addEventListener"in document){var g=!1,h=["click","keydown","mousedown","pointerdown","touchstart"];h.forEach(function(t){document.addEventListener(t,a,!1)})}l(f)}},{}],6:[function(t,e,n){function r(t,e){if(!i)return!1;if(t!==i)return!1;if(!e)return!0;if(!o)return!1;for(var n=o.split("."),r=e.split("."),a=0;a<r.length;a++)if(r[a]!==n[a])return!1;return!0}var i=null,o=null,a=/Version\/(\S+)\s+Safari/;if(navigator.userAgent){var f=navigator.userAgent,c=f.match(a);c&&f.indexOf("Chrome")===-1&&f.indexOf("Chromium")===-1&&(i="Safari",o=c[1])}e.exports={agent:i,v ...
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/humans.txt" rel="author"/>
# <link href="https://skyandtelescope.org/xmlrpc.php" rel="pingback"/>
# <link href="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/favicon.ico" rel="icon" sizes="16x16" type="image/x-icon"/>
# <!-- This site is optimized with the Yoast SEO Premium plugin v17.4 (Yoast SEO v17.4) - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="Keep up with the latest on exoplanets - from hot Jupiters to super-Earths and Earth-like planets, the hunt for the next pale blue dot continues." name="description">
# <meta content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
# <link href="https://skyandtelescope.org/astronomy-news/exoplanets/" rel="canonical"/>
# <link href="https://skyandtelescope.org/astronomy-news/exoplanets/page/2/" rel="next"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Exoplanets Archives" property="og:title"/>
# <meta content="Keep up with the latest on exoplanets - from hot Jupiters to super-Earths and Earth-like planets, the hunt for the next pale blue dot continues." property="og:description"/>
# <meta content="https://skyandtelescope.org/astronomy-news/exoplanets/" property="og:url"/>
# <meta content="Sky &amp; Telescope" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@skyandtelescope" name="twitter:site"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://skyandtelescope.org/#organization","name":"Sky & Telescope","url":"https://skyandtelescope.org/","sameAs":["https://www.facebook.com/pages/Sky-Telescope-Magazine/66274830772","https://www.instagram.com/skyandtelescopemag/","https://twitter.com/skyandtelescope"],"logo":{"@type":"ImageObject","@id":"https://skyandtelescope.org/#logo","inLanguage":"en-US","url":"https://skyandtelescope.org/wp-content/uploads/SkyLogo_140px.gif","contentUrl":"https://skyandtelescope.org/wp-content/uploads/SkyLogo_140px.gif","width":140,"height":92,"caption":"Sky & Telescope"},"image":{"@id":"https://skyandtelescope.org/#logo"}},{"@type":"WebSite","@id":"https://skyandtelescope.org/#website","url":"https://skyandtelescope.org/","name":"Sky &amp; Telescope","description":"The essential guide to astronomy","publisher":{"@id":"https://skyandtelescope.org/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://skyandtelescope.org/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"CollectionPage","@id":"https://skyandtelescope.org/astronomy-news/exoplanets/#webpage","url":"https://skyandtelescope.org/astronomy-news/exoplanets/","name":"Exoplanets News | The Latest on Alien Worlds","isPartOf":{"@id":"https://skyandtelescope.org/#website"},"description":"Keep up with the latest on exoplanets - from hot Jupiters to super-Earths and Earth-like planets, the hunt for the next pale blue dot continues.","breadcrumb":{"@id":"https://skyandtelescope.org/astronomy-news/exoplanets/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://skyandtelescope.org/astronomy-news/exoplanets/"]}]},{"@type":"BreadcrumbList","@id":"https://skyandtelescope.org/astronomy-news/exoplanets/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://skyandtelescope.org/"},{"@type":"ListItem","position":2,"name":"Astronomy &amp; Observing News","item":"https://skyandtelescope.org/astronomy-news/"},{"@type":"ListItem","position":3,"name":"Exoplanets"}]}]}</script>
# <!-- / Yoast SEO Premium plugin. -->
# <link href="//skyandtelescope.org" rel="dns-prefetch"/>
# <link href="//cdn.jsdelivr.net" rel="dns-prefetch"/>
# <link href="//use.fontawesome.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/skyandtelescope.org\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.6"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://skyandtelescope.org/wp-includes/css/dist/block-library/style.min.css?ver=5.6" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/plugins/beaf-before-and-after-gallery/assets/css/twentytwenty.css?ver=5.6" id="bafg_twentytwenty-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/plugins/beaf-before-and-after-gallery/assets/css/bafg-style.css?ver=5.6" id="bafg-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/plugins/constant-contact-forms/assets/css/style.css?ver=1.8.2" id="ctct_form_styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/plugins/theme-my-login/assets/styles/theme-my-login.min.css?ver=7.0.15" id="theme-my-login-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.css?ver=1" id="hc/slick/css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/dist/style.css?ver=5cd08214eb3d04c33a3f267c7b906ed3" id="hc/style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://use.fontawesome.com/releases/v5.14.0/css/all.css?ver=5.14.0" id="wpbdp_font_awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/plugins/business-directory-plugin/assets/css/widgets.min.css?ver=5.12.1" id="wpbdp-widgets-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/plugins/easy-fancybox/css/jquery.fancybox.min.css?ver=1.3.24" id="fancybox-css" media="screen" rel="stylesheet" type="text/css"/>
# <style id="fancybox-inline-css" type="text/css">
# #fancybox-content{border-color:#fff;}
# </style>
# <link href="https://skyandtelescope.org/wp-content/plugins/addthis/frontend/build/addthis_wordpress_public.min.css?ver=5.6" id="addthis_all_pages-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/plugins/business-directory-plugin/themes/default/assets/styles.css?ver=5.12.1" id="default-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://skyandtelescope.org/wp-content/plugins/wpbdp.css?ver=5.12.1" id="wpbdp-custom-0-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://skyandtelescope.org/wp-includes/js/jquery/jquery.min.js?ver=3.5.1" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="https://skyandtelescope.org/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.3.2" type="text/javascript"></script>
# <link href="https://skyandtelescope.org/wp-json/" rel="https://api.w.org/"/><link href="https://skyandtelescope.org/wp-json/wp/v2/categories/21" rel="alternate" type="application/json"/><link href="https://skyandtelescope.org/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://skyandtelescope.org/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.6" name="generator"/>
# <script type="text/javascript"><!--
# function powerpress_pinw(pinw_url){window.open(pinw_url, 'PowerPressPlayer','toolbar=0,status=0,resizable=1,width=460,height=320');	return false;}
# //-->
# </script>
# <link href="https://skyandtelescope.org/astronomy-news/exoplanets/feed/" rel="alternate" title="Exoplanets - Sky &amp; Telescope" type="application/rss+xml"/>
# <style></style>
# <meta content="v1" name="tec-api-version"/><meta content="https://skyandtelescope.org" name="tec-api-origin"/><link href="https://skyandtelescope.org/wp-json/tribe/events/v1/" rel="https://theeventscalendar.com/"/> <!-- Facebook Pixel Code -->
# <script>
# 						!function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# 				n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# 				n.push=n;n.loaded=!0;n.version='2.0';n.agent='dvpixelcaffeinewordpress';n.queue=[];t=b.createElement(e);t.async=!0;
# 				t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# 				document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
# 			var aepc_pixel = {"pixel_id":"357563535071425","user":[],"enable_advanced_events":"yes","fire_delay":"0"},
# 				aepc_pixel_args = [],
# 				aepc_extend_args = function( args ) {
# 					if ( typeof args === 'undefined' ) {
# 						args = {};
# 					}
#
# 					for(var key in aepc_pixel_args)
# 						args[key] = aepc_pixel_args[key];
#
# 					return args;
# 				};
#
# 			// Extend args
# 			if ( 'yes' === aepc_pixel.enable_advanced_events ) {
# 				aepc_pixel_args.userAgent = navigator.userAgent;
# 				aepc_pixel_args.language = navigator.language;
#
# 				if ( document.referrer.indexOf( document.domain ) < 0 ) {
# 					aepc_pixel_args.referrer = document.referrer;
# 				}
# 			}
#
# 			fbq('init', aepc_pixel.pixel_id, aepc_pixel.user);
#
# 						setTimeout( function() {
# 				fbq('track', "PageView", aepc_pixel_args);
# 			}, aepc_pixel.fire_delay * 1000 );
# 		</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=357563535071425&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <style>
#         /*homepage*/
# .home .podcasts .podcast .btn {width:200px !important}
#
# .home .podcasts .podcast .btn {
# border: 1px solid #212529}
#
# p.category .icon-bookmark {margin-left:2px}
#
# /*calendar*/
# a.btn-calendar {
#         background-color: #fff;
#     color: #CB2026;
#     text-transform: uppercase;
#     padding: 15px;
#     font-family: 'Helvetica Neue Condensed Bold';
#     border: 1px solid #CB2026;}
#
# .tribe_community_edit a.btn-calendar {
#     display: none;
# }
#
# .tribe-section.tribe-section-taxonomy {
# display:none}
#
# .tribe-events-community-footer:after {
#     content: 'Please wait after clicking button as submission may take a few moments. Do not reload page or click button more than once.';
#     display: block;
#     color: #000;
#     font-size: 13px;
# }
#
# .tribe-common-c-btn.tribe-events-c-search__button
# {background:#cb2026}
#
# header.tribe-events-calendar-list__event-header {
#     background: #fff;
# }
#
# .tribe-common .tribe-common-c-btn:focus, .tribe-common .tribe-common-c-btn:hover, .tribe-common a.tribe-common-c-btn:focus, .tribe-common a.tribe-common-c-btn:hover {
#     background-color: #fff;
# color:#cb2026;
# border:1px solid #cb2026
# }
#
# a.tribe-events-calendar-list__event-title-link.tribe-common-anchor-thin {
#     color: #cb2026;
# }
#
# /*date picker*/
# .tribe-events .datepicker .day.active, .tribe-events .datepicker .day.active.focused, .tribe-events .datepicker .day.active:focus, .tribe-events .datepicker .day.active:hover, .tribe-events .datepicker .month.active, .tribe-events .datepicker .month.active.focused, .tribe-events .datepicker .month.active:focus, .tribe-events .datepicker .month.active:hover, .tribe-events .datepicker .year.active, .tribe-events .datepicker .year.active.focused, .tribe-events .datepicker .year.active:focus, .tribe-events .datepicker .year.active:hover {
#     background: #cb2026;
# }
#
# /*calendar event page*/
# .tribe-events-cal-links .tribe-events-gcal, .tribe-events-cal-links .tribe-events-ical {color:#cb2026}
#
# .tribe-events-event-meta a, .tribe-events-event-meta a:visited {
#     color: #cb2026;
# }
# p.tribe-events-back a {
#     color: #cb2026 !important;
# }
#
# /*hiding export button on calendar*/
# .tribe-events .tribe-events-c-ical__link {
#     display: none;
# }
#
# /*mobile view for calendar*/
# header.tribe-events-header.tribe-events-header--has-event-search {
#     background: transparent !important;
# }
#
# .tribe-common .tribe-common-c-svgicon {
#     color: #cb2026;
# }
#
# .tribe-events .tribe-events-c-events-bar__search-button:before
#  {
#     background-color: #cb2026;
# }
#
# /*submisison form width fix*/
# span.select2.select2-container.select2-container--default.tribe-dropdown.linked-post-dropdown.tribe-dropdown-created {
#     max-width: 350px;
# }
#
# /*submission form other stuff*/
# #post.events-community-submit {
#     background: #cb2026;
#     border: none;
#     padding: 25px;
#     font-size: 16px;
# }
#
# #post.events-community-submit:hover {
# background:#fff;
# color:#cb2026;border:1px solid #cb2026}
#
# .tribe-community-events .events-community-post-content>input, .tribe-community-events .events-community-post-content>textarea, .tribe-community-events .events-community-post-title>input, .tribe-community-events .events-community-post-title>textarea {
# border:1px solid #000 }
#
# header.my-events-header {
#     border-bottom: none;
# }
#
# h2.my-events {
#     font-size: 20px !important;
#     font-family: 'Helvetica Neue Condensed Bold';
#     text-transform: uppercase;
#     color: #000 !important;
# }
#
# .tribe-community-events {background:#fff;border:1px solid #000}
#
# .my-events-header a.tribe-button.tribe-button-secondary {
#     font-family: 'Helvetica Neue Condensed Bold';
#     font-weight: bold;
#     font-size: 14px;
#     background: #fff;
#     color: #cb2026;
#     border: 2px solid #cb2026;
# }
#
# a.tribe-button.tribe-button-secondary:hover {
#     background: #cb2026;
#     color: #fff;
# }
#
# .tribe-section.tribe-section-datetime.event-datepickers.event-time.eventForm {
#     border: 1px solid #000;
# }
#
# .tribe-section.tribe-section-image-uploader {
#     border: 1px solid #000;
# }
#
# div#event_tribe_venue {
#     border: 1px solid #000;
# }
#
# div#event_tribe_organizer {
#     border: 1px solid #000;
# }
#
# .tribe-section.tribe-section-website {
#     border: 1px solid #000;
# }
#
# .tribe-section.tribe-section-cost {
#     border: 1px solid #000;
# }
#
# #post.events-community-submit {
#   background: #cb2026;
#     border: none;
#     padding: 25px;
#     font-size: 16px;
# }
#
# textarea#post_content {
#     font-size: 14px;
# }
#
# .tribe-section-content label {
#     color: #000;
# }
#
# /*add new event on event listings page*/
# a.tribe-button.tribe-button-primary.add-new {
#     background: #cb2026;
# }
# a.tribe-button.tribe-button-primary.add-new:hover {color:#cb2026;background:#fff;border:1px solid #cb2026}
#
# /*jupiter tool color fix
# #UniversalTimes td {
#     background-color: #fff;
# } */
#
# /* newsletter sidebar hide disclaimer*/
# .c-newsletter sub {
#     display: none !important;
# }
#
# /*get rid of recaptcha badge*/
# .grecaptcha-badge {
# opacity: 0;
# }
#
# p.recaptcha {
#     font-size: 10px;
# }
#
# /*teaser styles*/
# .intro p {
#   margin-bottom:40px !important;
# }
#
# /*article table padding*/
# .wp-block-table tbody tr td
# {padding:5px}
#
# /*fonts for tables in posts*/
# .wp-block-table td {
# font-family: LyonText-Regular, serif;
# }
#
# /*font for lists*/
# ul li {
#     font-family: LyonText-Regular, serif;
# }
#
# /* fix for telescope calculator styling on astronomy-equipment/telescope-eyepiece-guide */
# .wrapper-post-content input:not([type='checkbox']):not([type='submit']) {
# padding-left:5px;
# text-transform:uppercase;}
#
# /* celestron image*/
# .c-block-podcast__sponsor
# {background-color:transparent}
#
# /*video caption styling*/
#  .wp-block-embed figcaption {
# font-family: "LyonText-Regular";
#     font-size: 13px;
#     color: #353535;
#     letter-spacing: 0;
#     line-height: 20px;
# }
#
# /* h2 margin on posts */
# .wrapper-post-content h2
# {margin-bottom:10px}
#
# /* red for tour sold out messages */
# p.tour-soldout
# {color: #cb2026}
#
# h3.tour-soldout
# {color: #cb2026}
#
# /* intro text on pages */
# p.intro{
# font-family: "Helvetica Neue";
#     font-size: 24px;
#     color: inherit;
#     letter-spacing: -0.1px;
#     line-height: 29px;
#     margin-bottom: 0;
# }
#
# .wrapper-post-content .intro * {
# text-transform:none}
#
# /*login remove capitalization*/
# .wrapper-post-content input:not([type='checkbox']):not([type='submit'])
# {text-transform:none}
#
# /*featured image caption color*/
# .above-the-fold__caption {color:#e3e3e3}
#
# /*video captions*/
# .wp-block-video figcaption
# {font-family: "LyonText-Regular";
#     font-size: 13px;
#     color: #353535;}
#
# /*change image width to 728 on desktop and 100% on phones but not ipad */
# @media (min-width: 1026px){
# .wrapper-post-content .wp-block-image {max-width:728px}}
#
# @media (max-width: 1000px){
# .wrapper-post-content .wp-block-image {max-width:100%}}
#
# /* change caption size on ipad pro landscape only*/
# @media  (min-width: 1366px)
# and (max-width: 1440px) {
# .wrapper-post-content .wp-block-image figcaption {
# width:250px}}
#
#
# /*club update form*/
# .page-id-255507444492 .wrapper-post-content label {
#     font-size: 15px;
# }
#
# /* featured image on dark sky post being dumb*/
# @media (min-width: 1026px) {
# .postid-255507445224 .above-the-fold .hero-image--portrait {
#   margin-left: 13% !important;
# }}
#
# @media (min-width: 992px) and (max-width:1025px) {
# .postid-255507445224 .above-the-fold .hero-image--portrait {
#   margin-left: 4% !important;
# }}
#
# /*form fonts*/
# .nf-form-content label {
#     font-family: LyonText-Regular, serif;
# font-weight:normal;
# font-size:16px !important;}
#
# /*ninja forms submit button*/
# .nf-form-content input[type=button], .nf-form-content input[type=submit]
#  {
# background:#cb2026 !important}
#
# /*newsletter signup page for AAS virtual conference and newsletter page and tours page*/
# .page-id-255507451105 .wrapper-post-content label
# {font-size:15px !important}
#
# .page-id-255507451105 .ctct-form-field label {
#     font-family: 'Helvetica Neue',Arial,sans-serif;}
#
# .page-id-255507451105 legend#list_memberships_label_0 {
#     font-size: 15px}
#
# .page-id-14467345 .ctct-form-field label {
#     font-family: 'Helvetica Neue',Arial,sans-serif;}
#
# .page-id-14467345 legend#list_memberships_label_0 {
#     font-size: 15px}
#
# .page-id-14467345 .wrapper-post-content label
# {font-size:15px !important}
#
# /*tours page newsletter*/
# .page-id-3070 form#ctct_form_1 p {
#     font-family: "Helvetica Neue Condensed Bold";
# }
#
# .page-id-3070 label#email_address_label_1 {
#     font-family: "Helvetica Neue Condensed Bold";
# }
#
# /* footer ad on category pages*/
# .c-ad--label.archive {
#     margin-top: 20px;
# }
#
# .c-ad.c-ad--embed.c-ad--footer.archive-ad {
#     margin-bottom: 0px;
# }
#
# /*View Gallery button on homepage carousel*/
#
# @media (max-width: 376px){
# a.button.button--2.ko.vg {
#     margin-bottom: 10px;
# }}
#
# /*making tool links on saturn tool page red*/
# a:not([href]) {color: #CB2026;}
#
# /*update text in red*/
# h2.update {color:#CB2026;
#     margin-top: 20px;
# }
#
# h3.update {color:#CB2026;
#     margin-top: 20px; font-weight:bold;
# }
#
# /* temporary removal of See All link for recurring events because it doesn't go anywhere */
# .event-is-recurring {
#     display: none;
# }
#
# /*eyepiece calculators*/
# input.reset-button {
#     background: #CB2026 !important;
#     color: #fff;
# }
# input.calculate-button {background-color: #000 !important;
# color:#fff}
#
# table.eyepiece {
#     border: 1px solid #000;
# }
#
# table.fieldofview {
#     border: 1px solid #000;
# }
#
# /*magnificaton formulas table */
# span.upper {
#     border-bottom: 1px solid #000;
#     padding-bottom: 3px;
# }
#
# /*jupiter app box*/
# table.jupiter-app {
#     margin-bottom: 20px;
# }
#
# /*blockquotes*/
# blockquote.wp-block-quote:before {
#     color: #ccc;
#     content: "\201C";
#     font-size: 4em;
#     line-height: 0.1em;
#     margin-right: 0.25em;
#     vertical-align: -0.4em;
# }
# blockquote.wp-block-quote {
#     background: #f9f9f9;
#     border-left: 10px solid #ccc;
#     margin: 1.5em 10px;
#     padding: 0.5em 10px;}
#
# /*changing ordered list to have correct font*/
#
# ol li {
#     font-family: 'LyonText-Regular';
# }
#
# /* celestial objects to observe category list page /celestial-objects-observe/  */
# .wp-block-columns.are-vertically-aligned-center.objects-observe {
#     margin-bottom: -30px;
# }
# @media (max-width: 767px) {
# .page-id-255181793 figure.wp-block-image.size-large.is-resized {margin-bottom: 20px;}}
#
# /*hiding comment buttons on TREE RINGS HELP RECONSTRUCT A MILLENNIUM OF THE SUN'S ACTIVITY*/
# .postid-255507463187 button.button.button--2.js-comment-show-form {
# display:none}
#
# .postid-255507463187 p.button.button--2.js-comment-show-form {
# display:none}
#
# h3 a {
#     text-decoration: underline;}
#
# /* 2021 eclipse tour form pages */
# .page-id-255507464729 .wrapper-post-content label {font-size:18px !important;     line-height: 1.3em;
# }
#
# .page-id-255507464729  .wrapper-post-content input
# { box-shadow:none !important}
#
# .page-id-255507464726 .wrapper-post-content label {font-size:18px !important;     line-height: 1.3em;
# }
#
# .page-id-255507464726  .wrapper-post-content input
# { box-shadow:none !important}
#
# /*image submission form*/
# .page-id-246617945 .gform_wrapper.gf_browser_chrome .gfield_checkbox li input, .gform_wrapper.gf_browser_chrome .gfield_checkbox li input[type=checkbox]{
#     margin-top: -2px;
# }
#
# /*category indentatinos for image submission form*/
# .page-id-246617945 label#label_1_8_7 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 li.gchoice_1_8_7 {
#     text-indent: 20px;
# }
#
# .page-id-246617945 label#label_1_8_8 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 li.gchoice_1_8_8 {
#     text-indent: 20px;
# }
#
# .page-id-246617945 .gform_wrapper ul.gfield_checkbox li label{font-family: 'LyonText-Regular';}
#
# .page-id-246617945 ul#input_1_8 {
#     text-indent: 10px;
# }
#
#
# .page-id-246617945 label#label_1_8_1 {
#     text-indent: 0px;}
#
# .page-id-255507466368 li.gchoice_1_8_1 {
#     text-indent: 0px;
# }
#
# /*hiding first category option because it needs to be checked for other categories to work. hidden so that users cannot uncheck it (the Astronomy Picture praent category) */
# .page-id-246617945 li.gchoice_1_8_1 {
#     display: none;
# }
#
# .page-id-246617945 label#label_1_8_2 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_3 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_4 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_5 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_6 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_9 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_10 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_11 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_12 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_13 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_14 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_15 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_16 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_17 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_18 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_8_19 {
#     text-indent: 0px;
# }
#
# .page-id-246617945 label#label_1_11_1 {
#    margin-top: 8px;
# }
#
# .page-id-246617945 .gform_footer.top_label:after {
#     content: 'Please wait after clicking Submit. Do not click button twice.';
#     font-size: 12px;
# }
#
# /*club submissiong form and update form confirmation message */
# div#gform_confirmation_message_3 {
#     font-family: 'LyonText-Regular';
#     font-size: 18px;
#     font-weight: bold;
#     color: #cb2026;
# }
#
# div#gform_confirmation_message_4
# {
#     font-family: 'LyonText-Regular';
#     font-size: 18px;
#     font-weight: bold;
#     color: #cb2026;
# }
#
# /*share your story form*/
# .page-id-255507450652 .wrapper-post-content input:not([type='checkbox']):not([type='submit']) {
# box-shadow:none;
# min-width:0px !important;
# }
#
# /*star party door prize confirmation*/
# div#gform_confirmation_message_6
# {
#     font-family: 'LyonText-Regular';
#     font-size: 18px;
#     font-weight: bold;
#     color: #cb2026;
# }
#
# /*date picker for gravity forms*/
# .ui-datepicker-header.ui-widget-header.ui-helper-clearfix.ui-corner-all {
#     background-color: #cb2026;
# }
#
# .ui-datepicker-calendar .ui-state-default {
# background:#fff !important;}
#
# .ui-datepicker td a, .ui-datepicker td span {
# color:#000}
#
# select.ui-datepicker-month {
#     padding: 5px;
# }
#
# select.ui-datepicker-year {
#     padding: 5px;
# }
#
# /*virtual booth survey and raffle form*/
#
# .page-id-255507461159 .wrapper-post-content input:not([type='checkbox']):not([type='submit']) {
# box-shadow:none;
# min-width:0px !important;
# }
#
# div#gform_confirmation_message_11 {
#     font-family: 'LyonText-Regular';
#     font-size: 18px;
#     font-weight: bold;
#     color: #cb2026;
# }
#
# /*gravity forms align radio buttons*/
# .gfield_radio li input[type=radio] {
#     margin-top: 0px !important;
# }
#
# /*gravity forms remove box shadow from text inputs*/
# .wrapper-post-content textarea {
#     box-shadow: none;
# }
#
# /* hide tags on images so the one sean uses won't show*/
# .single-snt_photos .wrapper-post-content .tags
# {display: none !important;}
#
# /*caption styling for tables*/
# .wp-block-table.is-style-stripes figcaption {font-family: "LyonText-Regular";
#     font-size: 13px;
#     color: #353535;
#     letter-spacing: 0;
#     line-height: 20px;
#     text-align: center;
# }
#
# /*business directory css*/
# ul.wpbdp-categories.cf.wpbdp-categories-medium {
#     display: none;
# }
#
# .single-wpbdp_listing .wrapper-post-content input:not([type='checkbox']):not([type='submit']) {
#     min-width: 10px;
# }
#
# .single-wpbdp_listing .wrapper-post-content label {font-size:14px}
#
# .wpbdp-map-directions-config label {margin:5px}
# .wpbdp-map-directions-config {background:#fff}
#
# .wpbdp-map-directions-config h4 {font-size:17px}
#
# .wpbdp-listing .address-info .address-label {display:none}
#
# .listing-details.cf {line-height:1em}
#
# .wpbdp-listing .field-label {
# display:table;
#     margin-bottom: 5px;
# }
#
# .back-to-dir-buttons {
#     float: left;
# }
#
# .wpbdp-listing .listing-title a {font-family:'LyonText-Regular'}
#
# input#wpbdp-field-8-title {
#     display: none;}
#
# .wpbdp-url-field-col span.sublabel {
#     display: none;
# }
#
# #wpbdp-checkout-form-fields label, .wpbdp-form-field label {
#     font-size: 15px;
# }
#
# .wpbdp-main-box .submit-btn input[type="submit"] {
# color:#cb2026}
#
# a.search-back {
#     text-decoration: none;
#     border: 1px solid #cb2026;
#     padding: 10px;
#     font-weight: bold;
#     font-size: 15px;
# }
#
# #wpbdp-search-form-wrapper h3 {
#     font-family: 'LyonText-Regular';
#     font-size: 22px;
#     text-transform: capitalize;
#     border-bottom: 1px solid #e3e3e3;
# }
#
# #wpbdp-categories {
#     display: none;
# }
#
# @media (max-width: 768px){
# input.wpbdp-submit.wpbdp-button.submit {
#     margin-left: 1% !important;
# }
#
# .field.inner {
#     margin-left: 0px !important;
# }
#
# input.wpbdp-button.reset {
#     margin-bottom: 15px;
#     margin-left: 1%;
#     margin-top: 10%;
# }
#
# input.wpbdp-submit.wpbdp-button.submit {
#     font-size: 16px; }
# }
#
# /*subscribe page table*/
# @media (max-width: 768px){
# img.wp-image-255492957.size-full {
#     margin-bottom: 30px !important;
# }}
#
# /*toc page links to subscribe and index*/
# span.toc-subscribe a {
#     font-size: 20px;
#     font-family: 'Helvetica Neue Condensed Bold'; }
#
# .postid-255507475154 span.js-bookmark-post.icon-bookmark.media-block__bookmark.media-block__bookmark--ko {
#     display: none;
# }
#
# .postid-255507475154 .at-above-post.addthis_tool {
#     margin-top: 10px;
# }
#
# /*current issue in top top menu and main nav menu showing/hiding on mobile and margin*/
#
# @media (min-width: 813px) {
# a.nav-item.nav-link.currentissue-mobile {
# display:none}
# }
#
# a.btn.current-issue {
#     margin-left: -10px;
# }
#
# /* 80th anniversary badge
#
# .col-md-5.px-0.anniv {
# margin-left:-10px}  */
#         </style>
# <!-- Start GPT Tag -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#
#      // Responsive
#       var footerAd = googletag.sizeMapping().
#         addSize([1300, 0], [728, 90]).
#         addSize([330, 0], [320, 50]).
#         build();
#       var contentAd =  googletag.sizeMapping().
#         addSize([1300, 0], [320, 50]).
#         addSize([330, 0], [320, 50]).
#         build();
#       var tallAd =  googletag.sizeMapping().
#         addSize([768, 0], [300, 600]).
#         addSize([330, 0], [300, 250]).
#         build();
#
#
#
#     // googletag.defineSlot('/21837757904/SKY', [[320,50]], 'div-gpt-ad-2755042-5')
#     //          .setTargeting('test', ['off'])
#     //          .setTargeting('pos', ['bottom'])
#     //          .addService(googletag.pubads());
#         // Sidebar Ads
#     googletag.defineSlot('/21837757904/SKY', [[300,600],[300,250]], 'div-gpt-ad-2755042-6')
#             .defineSizeMapping(tallAd)
#              .setTargeting('test', ['off'])
#              .setTargeting('pos', ['right1'])
#              .addService(googletag.pubads());
#     googletag.defineSlot('/21837757904/SKY', [[300,600],[300,250]], 'div-gpt-ad-2755042-7')
#             .defineSizeMapping(tallAd)
#              .setTargeting('test', ['off'])
#              .setTargeting('pos', ['right2'])
#              .addService(googletag.pubads());
#     googletag.defineSlot('/21837757904/SKY', [[300,600],[300,250]], 'div-gpt-ad-2755042-8')
#             .defineSizeMapping(tallAd)
#              .setTargeting('test', ['off'])
#              .setTargeting('pos', ['right3'])
#              .addService(googletag.pubads());
#         // googletag.defineSlot('/21837757904/SKY', [[728,90]], 'div-gpt-ad-2755042-9')
#     //         .defineSizeMapping(contentAd)
#     //          .setTargeting('test', ['off'])
#     //          .setTargeting('pos', ['mid1'])
#     //          .addService(googletag.pubads());
#     // googletag.defineSlot('/21837757904/SKY', [[728,90]], 'div-gpt-ad-2755042-10')
#     //             .defineSizeMapping(contentAd)
#     //          .setTargeting('test', ['off'])
#     //          .setTargeting('pos', ['mid2'])
#     //          .addService(googletag.pubads());
#     // googletag.defineSlot('/21837757904/SKY', [[728,90]], 'div-gpt-ad-2755042-11')
#     //             .defineSizeMapping(contentAd)
#     //          .setTargeting('test', ['off'])
#     //          .setTargeting('pos', ['mid3'])
#     //          .addService(googletag.pubads());
#
#     // Footer Ad
#     googletag.defineSlot('/21837757904/SKY', [[728,90]], 'div-gpt-ad-2755042-4')
#             .defineSizeMapping(footerAd)
#              .setTargeting('test', ['off'])
#              .setTargeting('pos', ['bottom'])
#              .addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <!-- End GPT Tag -->
# <script type="text/javascript">
#         var bookmark_listing_url = 'https://skyandtelescope.org/bookmark/';
#     </script>
# </meta></meta></meta></head>
# <body class="archive category category-exoplanets category-21 tribe-no-js tribe-theme-sky-and-telescope-2020 ctct-sky-and-telescope-2020 header-theme--dark" data-pageid="255507477440" data-template="base.twig">
# <!-- Start after body script -->
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NJ7CPQ7" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!-- End after body script -->
# <header class="light-text">
# <div class="toolbar-theme--light topnav-wrapper">
# <div class="container">
# <div class="row">
# <div class="topnav">
# <ul>
# <li><span class="js-toolbar-location"></span><button id="updateLocation">Update Location</button></li>
# <li><img alt="Sunset Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-sunset.svg"/> SUNSET: <span class="js-tooltop-sunset"></span></li>
# <li>
# <img alt="Full Moon Icon" class="moon-type" data-theme-link="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-moon-waninggibbous.svg"/> <span class="js-tooltop-moon">MOON: 90% Waxing Gibbous</span></li>
# </ul>
# <a class="btn btn3 star-chart-link" data-ga='{"event" : "skyChartCtaClick", "sky_chart_action" : "Click to Header CTA", "sky_chart_label" : "/interactive-sky-chart"}' href="/interactive-sky-chart" target="">Interactive star Chart</a>
# </div>
# </div>
# </div>
# </div>
# <div class="subtopnav-wrapper">
# <div class="container">
# <div class="row no-gutters">
# <div class="col-md-12">
# <div class="subtopnav">
# <!-- <a href="login" class="bookmarkme"><img src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-bookmark-white.svg" alt="Bookmark Icon"/></a> -->
# <a class="btn" href="login">Login</a>
# <a class="btn current-issue" href="/skytel">Current Issue</a>
# <a class="btn subscribe-top" data-ga='{"event" : "newsletterInteraction", "newsletter_action" : "Subscription Submit", "newsletter_label" : "http://www.shopatsky.com"}' href="http://www.shopatsky.com" target="_blank">Shop at Sky</a>
# <a class="btn btn-search" href="#"><span>SEARCH</span> <img alt="Search Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-search-white.svg"/> </a>
# <div class="searchform-wrapper" style="background-color: #FFFFFF;position: absolute; top:0; right: 0;display:none;padding:13px 10px;z-index: 50;">
# <form action="https://skyandtelescope.org" class="search-form needs-validation form-inline" method="get" novalidate="" role="search">
# <div class="input-group">
# <input aria-describedby="inputGroupPrepend" class="search-field form-control" id="validationCustomUsername" name="s" placeholder="Search" required="" type="search" value=""/>
# <div class="input-group-prepend">
# <button class="input-group-text btn" id="inputGroupPrepend" type="submit"><img alt="Search Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-search.svg"/></button>
# </div>
# </div>
# <span style="padding:0  10px;"><a class="close-search" href="#">CLOSE <img alt="Close Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-close.svg"/></a></span>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container nav-container">
# <nav class="navbar navbar-expand-lg navbar-light">
# <div class="brand-wrapper-mobile" style="text-align:center;">
# <a class="navbar-nav-mobile" href="https://skyandtelescope.org">
# <img alt="Sky &amp; Telescope Logo" height="40" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/sky-and-telescope-white-logo.svg" width="317"/>
# </a>
# <p class="tagline">The Essential Guide to Astronomy</p>
# </div>
# <button aria-controls="navbarNavAltMarkup" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler nav-button" data-target="#navbarNavAltMarkup" data-toggle="collapse" type="button">
# <span id="nav-icon3">
# <span></span>
# <span></span>
# <span></span>
# <span></span>
# <small>MENU</small>
# </span>
# </button>
# <div class="collapse navbar-collapse" id="navbarNavAltMarkup">
# <div class="navbar-nav">
# <a class="nav-item nav-link menu-item menu-item-type-taxonomy menu-item-object-category current-category-ancestor current-menu-ancestor current-menu-parent current-category-parent menu-item-255507146 menu-item-has-children" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Category", "top_navigation_label" : "News"}' data-menu-current="field_5e30578910b33" href="https://skyandtelescope.org/astronomy-news/">News</a>
# <a class="nav-item nav-link menu-item menu-item-type-taxonomy menu-item-object-category menu-item-255507147 menu-item-has-children" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Category", "top_navigation_label" : "Observing"}' data-menu-current="field_5e291e7983def" href="https://skyandtelescope.org/observing/">Observing</a>
# <a class="nav-item nav-link menu-item menu-item-type-post_type menu-item-object-page menu-item-255507156" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Category", "top_navigation_label" : "Tools"}' data-menu-current="tools" href="https://skyandtelescope.org/tools/">Tools</a>
# </div>
# <div class="navbar-nav mx-auto brand">
# <div class="brand-wrapper" style="text-align:center;">
# <a class="navbar-nav" href="https://skyandtelescope.org">
# <img alt="Sky &amp; Telescope Logo" height="40" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/sky-and-telescope-white-logo.svg" width="317"/>
# </a>
# <p class="tagline">The Essential Guide to Astronomy</p>
# </div>
# </div>
# <div class="navbar-nav">
# <a class="nav-item nav-link menu-item menu-item-type-post_type menu-item-object-page menu-item-255507161 menu-item-has-children" data-menu-current="community" href="https://skyandtelescope.org/community/">Community</a>
# <a class="nav-item nav-link menu-item menu-item-type-post_type menu-item-object-page menu-item-255507269" data-menu-current="astronomy-travel" href="https://skyandtelescope.org/astronomy-travel/">Tours</a>
# <a class="nav-item nav-link menu-item menu-item-type-custom menu-item-object-custom menu-item-255506206 menu-item-has-children" data-menu-current="store" href="https://skyandtelescope.dragonforms.com/loading.do?omedasite=SKY_new" target="_blank">Subscribe</a>
# <a class="nav-item nav-link currentissue-mobile menu-item menu-item-type-custom menu-item-object-custom menu-item-255507475427" data-menu-current="current-issue" href="/skytel">Current Issue</a>
# </div>
# <div class="navbar-nav mobile-search">
# <form action="https://skyandtelescope.org" class="search-form needs-validation form-inline" method="get" novalidate="" role="search">
# <div class="search-wrapper">
# <button class="input-group-text btn" id="inputGroupPrependMobile" type="submit"><img alt="Search Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-search-white.svg"/></button>
# <input aria-describedby="inputGroupPrepend" class="search-field form-control" id="validationCustomKeyword" name="s" placeholder="Search" required="" type="search" value=""/>
# </div>
# </form>
# <div class="buttons">
# <a class="btn" href="login">Login</a>
# <a class="btn" data-ga='{"event" : "newsletterInteraction", "newsletter_action" : "Subscription Submit", "newsletter_label" : "http://www.shopatsky.com"}' href="http://www.shopatsky.com" target="_blank">Shop at Sky</a>
# </div>
# </div>
# </div>
# </nav>
# </div>
#
# </header>
# <main>
# <div class="above-the-fold post-category" style="background-color: ;">
# <div class="container">
# <div class="l-grid ko" style="flex-direction:column;">
# <div class="wrap subnav" data-current-parent="field_5e30578910b33">
# <ul class="subnav__group">
# <li class="subnav__item"><a class="subnav__link" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Sub-Category", "top_navigation_label" : "News-Observing News"}' href="https://skyandtelescope.org/astronomy-news/observing-news/" target="">Observing News</a></li>
# <li class="subnav__item"><a class="subnav__link" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Sub-Category", "top_navigation_label" : "News-Solar System"}' href="https://skyandtelescope.org/astronomy-news/solar-system/" target="">Solar System</a></li>
# <li class="subnav__item"><a class="subnav__link" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Sub-Category", "top_navigation_label" : "News-Spacecraft and Space Missions"}' href="https://skyandtelescope.org/astronomy-news/spacecraft-and-space-missions/" target="">Spacecraft and Space Missions</a></li>
# <li class="subnav__item"><a class="subnav__link active" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Sub-Category", "top_navigation_label" : "News-Exoplanets"}' href="https://skyandtelescope.org/astronomy-news/exoplanets/" target="">Exoplanets</a></li>
# <li class="subnav__item"><a class="subnav__link" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Sub-Category", "top_navigation_label" : "News-Galaxies"}' href="https://skyandtelescope.org/astronomy-news/galaxies/" target="">Galaxies</a></li>
# <li class="subnav__item"><a class="subnav__link" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Sub-Category", "top_navigation_label" : "News-Cosmology"}' href="https://skyandtelescope.org/astronomy-news/cosmology/" target="">Cosmology</a></li>
# <li class="subnav__item"><a class="subnav__link" data-ga='{"event" : "topNavigation", "top_navigation_action" : "Click to Sub-Category", "top_navigation_label" : "News-Black Holes"}' href="https://skyandtelescope.org/astronomy-news/black-holes/" target="">Black Holes</a></li>
# ...
# 		c0.72,0,1.42-0.27,1.97-0.76v1.09c-0.57,0.33-1.29,0.52-1.94,0.52c-2.1,0-3.84-1.67-3.84-3.8c0-2.18,1.75-3.88,3.92-3.88
# 		c0.65,0,1.3,0.16,1.86,0.5V5.42z"></path>
# <path d="M87.9,9.53l-0.84,1.85h-0.99l3.52-7.69l3.52,7.69h-0.99l-0.84-1.85H87.9z M89.59,5.71l-1.31,2.98h2.62L89.59,5.71z"></path>
# <polygon points="94.63,3.66 100.17,9.46 100.17,4.01 101.08,4.01 101.08,11.68 95.55,5.89 95.55,11.38 94.63,11.38 	"></polygon>
# <path d="M47.67,21.27l-0.84,1.85h-0.99l3.52-7.69l3.52,7.69h-0.99l-0.84-1.85H47.67z M49.36,17.44l-1.31,2.98h2.62L49.36,17.44z"></path>
# <path d="M57.58,17.14c-0.27-0.46-0.63-0.69-1.18-0.69c-0.59,0-1.23,0.4-1.23,1.05c0,0.58,0.57,0.88,1.03,1.06l0.53,0.21
# 		c1.05,0.41,1.83,0.99,1.83,2.22c0,1.34-1.04,2.3-2.36,2.3c-1.19,0-2.12-0.88-2.28-2.06l0.93-0.2c-0.01,0.81,0.64,1.4,1.43,1.4
# 		c0.79,0,1.36-0.66,1.36-1.44c0-0.79-0.64-1.13-1.27-1.4l-0.51-0.22c-0.84-0.36-1.6-0.84-1.6-1.87c0-1.19,1.06-1.91,2.17-1.91
# 		c0.82,0,1.5,0.4,1.9,1.11L57.58,17.14z"></path>
# <polygon points="62.5,23.12 61.58,23.12 61.58,16.58 59.83,16.58 59.83,15.74 64.25,15.74 64.25,16.58 62.5,16.58 	"></polygon>
# <path d="M70.44,23.12h-1.11L67.16,20h-0.38v3.12h-0.92v-7.37h1.11c0.65,0,1.36,0.01,1.94,0.34c0.62,0.36,0.97,1.06,0.97,1.76
# 		c0,1.06-0.7,1.94-1.77,2.06L70.44,23.12z M66.78,19.23h0.29c0.94,0,1.96-0.18,1.96-1.35c0-1.15-1.1-1.32-2-1.32h-0.24V19.23z"></path>
# <path d="M79.19,19.43c0,2.19-1.73,3.84-3.86,3.84c-2.13,0-3.86-1.65-3.86-3.84c0-2.11,1.75-3.84,3.86-3.84
# 		C77.44,15.59,79.19,17.32,79.19,19.43 M78.27,19.43c0-1.62-1.21-2.98-2.94-2.98s-2.94,1.36-2.94,2.98c0,1.68,1.35,2.98,2.94,2.98
# 		S78.27,21.11,78.27,19.43"></path>
# <polygon points="81.04,15.39 86.57,21.19 86.57,15.74 87.49,15.74 87.49,23.42 81.95,17.62 81.95,23.12 81.04,23.12 	"></polygon>
# <path d="M97.05,19.43c0,2.19-1.73,3.84-3.86,3.84c-2.13,0-3.86-1.65-3.86-3.84c0-2.11,1.75-3.84,3.86-3.84
# 		C95.3,15.59,97.05,17.32,97.05,19.43 M96.13,19.43c0-1.62-1.21-2.98-2.94-2.98c-1.73,0-2.94,1.36-2.94,2.98
# 		c0,1.68,1.35,2.98,2.94,2.98C94.78,22.41,96.13,21.11,96.13,19.43"></path>
# <polygon points="100.11,18.25 100.09,18.25 99.23,23.12 98.28,23.12 99.79,15.43 102.32,21.24 104.85,15.43 106.36,23.12
# 		105.41,23.12 104.55,18.25 104.53,18.25 102.32,23.27 	"></polygon>
# <rect height="7.37" width="0.92" x="108.13" y="15.74"></rect>
# <path d="M116.75,17.15c-0.53-0.47-1.25-0.72-1.94-0.72c-1.65,0-2.91,1.38-2.91,3.01c0,1.61,1.25,2.99,2.89,2.99
# 		c0.72,0,1.42-0.27,1.96-0.76v1.09c-0.57,0.33-1.29,0.52-1.94,0.52c-2.1,0-3.84-1.67-3.84-3.8c0-2.18,1.75-3.88,3.92-3.88
# 		c0.64,0,1.3,0.16,1.86,0.5V17.15z"></path>
# <path d="M119.94,21.27l-0.84,1.85h-0.99l3.52-7.69l3.52,7.69h-0.99l-0.84-1.85H119.94z M121.63,17.44l-1.31,2.98h2.62L121.63,17.44
# 		z"></path>
# <polygon points="127.63,22.27 129.87,22.27 129.87,23.12 126.71,23.12 126.71,15.74 127.63,15.74 	"></polygon>
# <path d="M49.9,28.88c-0.27-0.46-0.63-0.69-1.18-0.69c-0.59,0-1.23,0.4-1.23,1.05c0,0.58,0.57,0.88,1.03,1.06l0.53,0.21
# 		c1.05,0.41,1.83,0.99,1.83,2.22c0,1.34-1.04,2.3-2.36,2.3c-1.19,0-2.12-0.88-2.28-2.06l0.93-0.2c-0.01,0.81,0.64,1.4,1.43,1.4
# 		c0.79,0,1.36-0.66,1.36-1.44c0-0.79-0.64-1.13-1.27-1.4l-0.51-0.22c-0.84-0.36-1.6-0.84-1.6-1.87c0-1.19,1.06-1.91,2.17-1.91
# 		c0.82,0,1.5,0.4,1.9,1.11L49.9,28.88z"></path>
# <path d="M60.01,31.16c0,2.19-1.73,3.84-3.86,3.84c-2.13,0-3.86-1.65-3.86-3.84c0-2.11,1.75-3.84,3.86-3.84
# 		C58.26,27.32,60.01,29.05,60.01,31.16 M59.09,31.16c0-1.62-1.21-2.98-2.94-2.98c-1.73,0-2.94,1.36-2.94,2.98
# 		c0,1.68,1.35,2.98,2.94,2.98C57.74,34.15,59.09,32.85,59.09,31.16"></path>
# <path d="M67.28,28.89c-0.53-0.47-1.25-0.72-1.95-0.72c-1.65,0-2.91,1.38-2.91,3.01c0,1.61,1.25,2.99,2.89,2.99
# 		c0.72,0,1.42-0.27,1.96-0.76v1.09c-0.57,0.33-1.29,0.52-1.94,0.52c-2.1,0-3.84-1.67-3.84-3.8c0-2.18,1.75-3.88,3.92-3.88
# 		c0.64,0,1.3,0.16,1.86,0.5V28.89z"></path>
# <rect height="7.37" width="0.92" x="69.14" y="27.48"></rect>
# <polygon points="72.36,27.48 76.32,27.48 76.32,28.32 73.28,28.32 73.28,30.38 76.23,30.38 76.23,31.22 73.28,31.22 73.28,34.01
# 		76.32,34.01 76.32,34.85 72.36,34.85 	"></polygon>
# <polygon points="80.46,34.85 79.54,34.85 79.54,28.32 77.79,28.32 77.79,27.48 82.21,27.48 82.21,28.32 80.46,28.32 	"></polygon>
# <polygon points="83.32,27.48 84.38,27.48 86.19,30.63 88,27.48 89.05,27.48 86.65,31.64 86.65,34.85 85.73,34.85 85.73,31.64 	"></polygon>
# </g>
# </svg>
# <p>Copyright ©2021 AAS Sky Publishing LLC. All rights reserved.</p>
# </div>
# </img></div>
# </div>
# <div class="col-md-6 col-lg-7 footer-links">
# <div class="footer-links-right">
# <div class="row footer-separator-inner">
# <div class="footer-links-inner col-lg-8 hidden-sm-down">
# <h5>About S&amp;T</h5>
# <div class="footer-link-set">
# <ul class="two-columns gap-30">
# <li><a href="https://skyandtelescope.org/about/" target="_self">About Us</a></li>
# <li><a href="https://skyandtelescope.org/about/meet-the-staff/" target="_self">Meet the Staff</a></li>
# <li><a href="https://skyandtelescope.org/about/job-opportunities/" target="_self">Job Opportunities</a></li>
# <li><a href="https://skyandtelescope.org/australian-edition-sky-telescope/" target="_self">Australian Edition</a></li>
# <li><a href="https://www.shopatsky.com" target="_blank">Shop @ Sky</a></li>
# <li><a href="https://skyandtelescope.org/contact-us/" target="_self">Contact Us</a></li>
# <li><a href="/subscriber-services/" target="_self">Subscriber Services</a></li>
# <li><a href="https://skyandtelescope.org/help/" target="_self">Help &amp; Resources</a></li>
# <li><a href="https://skyandtelescope.org/privacy-policy/" target="_self">Privacy Policy</a></li>
# </ul>
# </div>
# </div>
# <div class="footer-links-inner col-lg-4 adjust">
# <div class="footer-link-set social">
# <ul>
# <li><a href="https://twitter.com/skyandtelescope" target="_blank"><img alt="Twitter Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-social-twitter.svg"/></a></li>
# <li><a href="https://www.facebook.com/pages/Sky-Telescope-Magazine/66274830772" target="_blank"><img alt="Facebook Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-social-facebook.svg"/></a></li>
# <li><a href="https://www.instagram.com/skyandtelescopemag" target="_blank"><img alt="Instagram Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-social-instagram.svg"/></a></li>
# <li><a href="https://www.youtube.com/user/SkyandTelescopeMedia" target="_blank"><img alt="Youtube Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/YouTube.svg"/></a></li>
# <li><a href="/subscribing-sky-telescope-rss-feeds" target="_blank"><img alt="RSS Feed Icon" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/src/img/icon-social-rss.svg"/></a></li>
# </ul>
# </div>
# <a class="button button--2" data-ga='{"event" : "newsletterInteraction", "newsletter_action" : "Click to Footer - Join our Newsletter", "newsletter_label" : "/newsletter"}' href="/newsletter">Join Our Newsletter</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# <script>
# 		( function ( body ) {
# 			'use strict';
# 			body.className = body.className.replace( /\btribe-no-js\b/, 'tribe-js' );
# 		} )( document.body );
# 		</script>
# <script> /* <![CDATA[ */var tribe_l10n_datatables = {"aria":{"sort_ascending":": activate to sort column ascending","sort_descending":": activate to sort column descending"},"length_menu":"Show _MENU_ entries","empty_table":"No data available in table","info":"Showing _START_ to _END_ of _TOTAL_ entries","info_empty":"Showing 0 to 0 of 0 entries","info_filtered":"(filtered from _MAX_ total entries)","zero_records":"No matching records found","search":"Search:","all_selected_text":"All items on this page were selected. ","select_all_link":"Select all pages","clear_selection":"Clear Selection.","pagination":{"all":"All","next":"Next","previous":"Previous"},"select":{"rows":{"0":"","_":": Selected %d rows","1":": Selected 1 row"}},"datepicker":{"dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesMin":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Prev","currentText":"Today","closeText":"Done","today":"Today","clear":"Clear"}};/* ]]> */ </script><script data-cfasync="false" type="text/javascript">if (window.addthis_product === undefined) { window.addthis_product = "wpp"; } if (window.wp_product_version === undefined) { window.wp_product_version = "wpp-6.2.6"; } if (window.addthis_share === undefined) { window.addthis_share = {"passthrough":{"twitter":{"via":"skyandtelescope"}}}; } if (window.addthis_config === undefined) { window.addthis_config = {"data_track_clickback":true,"ui_atversion":"300"}; } if (window.addthis_plugin_info === undefined) { window.addthis_plugin_info = {"info_status":"enabled","cms_name":"WordPress","plugin_name":"Share Buttons by AddThis","plugin_version":"6.2.6","plugin_mode":"AddThis","anonymous_profile_id":"wp-32de68bf39e985d9c3a40197b730dc73","page_info":{"template":"categories","post_type":""}}; }
#                     (function() {
#                       var first_load_interval_id = setInterval(function () {
#                         if (typeof window.addthis !== 'undefined') {
#                           window.clearInterval(first_load_interval_id);
#                           if (typeof window.addthis_layers !== 'undefined' && Object.getOwnPropertyNames(window.addthis_layers).length > 0) {
#                             window.addthis.layers(window.addthis_layers);
#                           }
#                           if (Array.isArray(window.addthis_layers_tools)) {
#                             for (i = 0; i < window.addthis_layers_tools.length; i++) {
#                               window.addthis.layers(window.addthis_layers_tools[i]);
#                             }
#                           }
#                         }
#                      },1000)
#                     }());
#                 </script> <script async="async" data-cfasync="false" src="https://s7.addthis.com/js/300/addthis_widget.js#pubid=ra-6009c94378a702f5" type="text/javascript"></script><script id="bafg_event_move-js" src="https://skyandtelescope.org/wp-content/plugins/beaf-before-and-after-gallery/assets/js/jquery.event.move.js" type="text/javascript"></script>
# <script id="bafg_twentytwenty-js" src="https://skyandtelescope.org/wp-content/plugins/beaf-before-and-after-gallery/assets/js/jquery.twentytwenty.js" type="text/javascript"></script>
# <script id="bafg_custom_js-js" src="https://skyandtelescope.org/wp-content/plugins/beaf-before-and-after-gallery/assets/js/bafg-custom-js.js" type="text/javascript"></script>
# <script id="ctct_frontend_forms-js" src="https://skyandtelescope.org/wp-content/plugins/constant-contact-forms/assets/js/ctct-plugin-frontend.min.js?ver=1.8.2" type="text/javascript"></script>
# <script id="ctct_frontend_forms-js-after" type="text/javascript">
# function ctctEnableBtn(){ jQuery( "#ctct-submitted" ).attr( "disabled", false ); }function ctctDisableBtn(){ jQuery( "#ctct-submitted" ).attr( "disabled", "disabled" ); }
# </script>
# <script id="theme-my-login-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var themeMyLogin = {"action":"","errors":[]};
# /* ]]> */
# </script>
# <script id="theme-my-login-js" src="https://skyandtelescope.org/wp-content/plugins/theme-my-login/assets/scripts/theme-my-login.min.js?ver=7.0.15" type="text/javascript"></script>
# <script id="hc/scripts-js" src="https://skyandtelescope.org/wp-content/themes/sky-and-telescope-2020/dist/script.js?ver=49290c0b5d0685cd999f82d1e87a6166" type="text/javascript"></script>
# <script id="jquery-fancybox-js" src="https://skyandtelescope.org/wp-content/plugins/easy-fancybox/js/jquery.fancybox.min.js?ver=1.3.24" type="text/javascript"></script>
# <script id="jquery-fancybox-js-after" type="text/javascript">
# var fb_timeout, fb_opts={'overlayShow':true,'hideOnOverlayClick':true,'showCloseButton':true,'margin':20,'centerOnScroll':true,'enableEscapeButton':true,'autoScale':true };
# if(typeof easy_fancybox_handler==='undefined'){
# var easy_fancybox_handler=function(){
# jQuery('.nofancybox,a.wp-block-file__button,a.pin-it-button,a[href*="pinterest.com/pin/create"],a[href*="facebook.com/share"],a[href*="twitter.com/share"]').addClass('nolightbox');
# /* IMG */
# var fb_IMG_select='a[href*=".jpg"]:not(.nolightbox,li.nolightbox>a),area[href*=".jpg"]:not(.nolightbox),a[href*=".jpeg"]:not(.nolightbox,li.nolightbox>a),area[href*=".jpeg"]:not(.nolightbox),a[href*=".png"]:not(.nolightbox,li.nolightbox>a),area[href*=".png"]:not(.nolightbox),a[href*=".gif"]:not(.nolightbox,li.nolightbox>a),area[href*=".gif"]:not(.nolightbox)';
# jQuery(fb_IMG_select).addClass('fancybox image');
# var fb_IMG_sections=jQuery('.gallery,.wp-block-gallery,.tiled-gallery,.wp-block-jetpack-tiled-gallery');
# fb_IMG_sections.each(function(){jQuery(this).find(fb_IMG_select).attr('rel','gallery-'+fb_IMG_sections.index(this));});
# jQuery('a.fancybox,area.fancybox,li.fancybox a').each(function(){jQuery(this).fancybox(jQuery.extend({},fb_opts,{'transitionIn':'elastic','easingIn':'easeOutBack','transitionOut':'elastic','easingOut':'easeInBack','opacity':false,'hideOnContentClick':false,'titleShow':true,'titlePosition':'over','titleFromAlt':true,'showNavArrows':true,'enableKeyboardNav':true,'cyclic':false}))});};
# jQuery('a.fancybox-close').on('click',function(e){e.preventDefault();jQuery.fancybox.close()});
# };
# var easy_fancybox_auto=function(){setTimeout(function(){jQuery('#fancybox-auto').trigger('click')},1000);};
# jQuery(easy_fancybox_handler);jQuery(document).on('post-load',easy_fancybox_handler);
# jQuery(easy_fancybox_auto);
# </script>
# <script id="jquery-easing-js" src="https://skyandtelescope.org/wp-content/plugins/easy-fancybox/js/jquery.easing.min.js?ver=1.4.1" type="text/javascript"></script>
# <script id="jquery-mousewheel-js" src="https://skyandtelescope.org/wp-content/plugins/easy-fancybox/js/jquery.mousewheel.min.js?ver=3.1.13" type="text/javascript"></script>
# <script id="wp-embed-js" src="https://skyandtelescope.org/wp-includes/js/wp-embed.min.js?ver=5.6" type="text/javascript"></script>
# <script id="aepc-pixel-events-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var aepc_pixel_events = {"custom_events":{"AdvancedEvents":[{"params":{"login_status":"not_logged_in","tax_category":"Exoplanets","object_id":21,"object_type":"cat_archive"},"delay":0}]}};
# /* ]]> */
# </script>
# <script id="aepc-pixel-events-js" src="https://skyandtelescope.org/wp-content/plugins/pixel-caffeine/build/frontend.js?ver=2.0.7" type="text/javascript"></script>
# <style></style>
# <!-- Start before_body script -->
# <!-- Begin Constant Contact Active Forms -->
# <script> var _ctct_m = "9c6d3b98196c3e118d9605cb2c3c8306"; </script>
# <script async="" defer="" id="signupScript" src="//static.ctctcdn.com/js/signup-form-widget/current/signup-form-widget.min.js"></script>
# <!-- End Constant Contact Active Forms -->
# <!-- End before_body script -->
# <div data-ga='{
#         "event: "dataLayer-initialized",
#         "loginStatus" : "not logged in",
#         "contentCategories" : "",
#         "articleTitle" : "Did We Find a Planet in Another Galaxy?",
#         "articleAuthor" : "Monica Young",
#         "articlePublish" : "November 1, 2021",
#         "pageType" : "post",
#         "eventTitle" : "",
#
#         } ' data-ga-initialized=""></div>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"NRJS-8cb8ee238900f71e051","applicationID":"517838593","transactionName":"NAAAZkNUV0oFVRZRCQ1KI1FFXFZXS1cQWw4KEwc=","queueTime":0,"applicationTime":2450,"atts":"GEcDEAtOREQ=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>
